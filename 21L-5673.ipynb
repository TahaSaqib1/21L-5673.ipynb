# %% [markdown]
# # Introduction To Data Science – Assignment 1
#
# ---
#
# ### Sections A – B – C – D
#
# ---
#
# ***Instructions***
#
# Due Date: Sunday 18th September 2022 – 11:59PM
#
# Name the file in the format Lyyxxxx and save it as .ipynb (e.g. L201234.ipynb)
#
# Submission will be taken on **GitHub and Google Classroom (submit the .ipynb file)** - Instructions to upload onto GitHub are provided in the link https://docs.google.com/document/d/1BR1ULOGeGWJVU6Rr6Qty1FR-quVRZyRvQGII6nEs-wo/edit?usp=sharing
#
# After uploading and submitting the .ipynb file onto Google Classroom, also private comment the link to the GitHub repository.
#
# All source files needed to complete this assignment can be found on the following Google Drive link https://drive.google.com/drive/folders/1VrkaVcExGWqilSeh50WZe4gUBjmUiJ9b?usp=sharing
#
# TA Emails
#
# Section A, C - Muhammad Maarij l192347@lhr.nu.edu.pk
#
# Section B, D - Hira Ijaz l192377@lhr.nu.edu.pk
#
# Happy Coding 😊
#
# ---

# %% [markdown]
# ---
# ## Question 1
# ---

# %% [markdown]
# Define a procedure called "check_input" that takes an input as a square list of lists (2D Matrix of N x N) and returns a boolen "true" if the input is valid or "false" otherwise, according to the following criteria.
#
# 1. Each coloumn must contain numbers from between 1 and N, with no duplicates.
# 2. Each row must contain numbers from between 1 and N, with no duplicates.

# %%
# define procedure here
def check_input(array):  # Function To check input
    row_count = 0
    col_count = 0
    x = len(array[0])
    for j in range(0,3):  #for column
        for i in range(1,3):
            if(array[0][j]==array[i][j] or type(array[i][j])==str):
                col_count = col_count + 1
    for i in range(0,x):  #for row
        for j in range(1,x):
            if(array[i][0]==array[i][j] or type(array[i][j])==str):
                row_count = row_count + 1   
    if(row_count==0 and col_count==0): #bool
        return True
    else:
        return False

# %%
# run this block to test code after defining the procedure

test1 = [[1, 2, 3],
        [2, 3, 1],
        [3, 1, 2]]

test2 = [[1, 2, 3, 4],
        [2, 3, 1, 3],
        [3, 1, 2, 3],
        [4, 4, 4, 4]]

test3 = [['a', 'b', 'c'],
        ['b', 'c', 'a'],
        ['c', 'a', 'b']]

def check_input(array):  # Function To check input
    row_count = 0
    col_count = 0
    x = len(array[0])
    for j in range(0,3):  #for column
        for i in range(1,3):
            if(array[0][j]==array[i][j] or type(array[i][j])==str):
                col_count = col_count + 1
    for i in range(0,x):  #for row
        for j in range(1,x):
            if(array[i][0]==array[i][j] or type(array[i][j])==str):
                row_count = row_count + 1   
    if(row_count==0 and col_count==0): #case for bool
        return True
    else:
        return False

print(check_input(test1)) # must return true
print(check_input(test2)) # must return false
print(check_input(test3)) # must return false
# Out:
# True
# False
# False

# %% [markdown]
# ---
# ## Question 2
# ---

# %%
import pandas as pd
#import numpy as np
data=pd.read_csv("StudentMarkSheet.csv")
print(data)
# Out:
#         Student name  Exam name   Exam date  Marks
# 0       James Walker    Biology  05/06/2016   31.0
# 1      Velma Clemons    Biology  05/06/2016   43.0
# 2     Kibo Underwood    Biology  05/06/2016   81.0
# 3        Louis Mcgee    Biology  05/06/2016   11.0
# 4       Phyllis Paul    Biology  05/06/2016   18.0
# ..               ...        ...         ...    ...
# 195       Yen Bowers  Sociology  21/06/2016   52.0
# 196        Ryan Pena  Sociology  21/06/2016   16.0
# 197  Portia Hamilton  Sociology  21/06/2016   34.0
# 198  Sydnee Chambers  Sociology  21/06/2016   76.0
# 199      Stacy Small  Sociology  21/06/2016   96.0
#
# [200 rows x 4 columns]

# %% [markdown]
# **Part A** - Import the file "StudentMarkSheet.csv" as a Pandas DataFrame and print the information for the dataframe

# %% [markdown]
# **Part B** - Remove any rows that do not contain all the data. Also print the following information.
#
# 1. Number of rows before
# 2. Number of rows containing null data
# 3. Number of rows after

# %%
import pandas as pd
import numpy as np
import csv

reader=csv.reader(open("StudentMarkSheet.csv"))
no_lines=len(list(reader))-1 #With Null
print(no_lines)
data=pd.read_csv("StudentMarkSheet.csv")
df1 = data.dropna()  #Without Null
print(df1)
NULL=len(df1)
print(NULL)
x=no_lines-NULL #N0. of null lines
print(x)
# Out:
# 200
#         Student name  Exam name   Exam date  Marks
# 0       James Walker    Biology  05/06/2016   31.0
# 1      Velma Clemons    Biology  05/06/2016   43.0
# 2     Kibo Underwood    Biology  05/06/2016   81.0
# 3        Louis Mcgee    Biology  05/06/2016   11.0
# 4       Phyllis Paul    Biology  05/06/2016   18.0
# ..               ...        ...         ...    ...
# 195       Yen Bowers  Sociology  21/06/2016   52.0
# 196        Ryan Pena  Sociology  21/06/2016   16.0
# 197  Portia Hamilton  Sociology  21/06/2016   34.0
# 198  Sydnee Chambers  Sociology  21/06/2016   76.0
# 199      Stacy Small  Sociology  21/06/2016   96.0
#
# [196 rows x 4 columns]
# 196
# 4

# %% [markdown]
# **Part C** - Print all the marks along with the subject for the student named "James Walker"

# %%
print(data[data['Student name']=='James Walker']) #specific student
# Out:
#      Student name    Exam name   Exam date  Marks
# 0    James Walker      Biology  05/06/2016   31.0
# 42   James Walker    Chemistry  15/06/2016   61.0
# 71   James Walker  Mathematics  29/07/2016   23.0
# 150  James Walker      Physics  10/06/2016  100.0
# 180  James Walker    Sociology  21/06/2016   73.0

# %% [markdown]
# ---
# ## Question 3
# ---

# %% [markdown]
# **Part A** - From the DataFrame created in Question 2, calculate the average marks for each subject

# %%
avbio=data[data["Exam name"]=="Biology"]
avbio=avbio["Marks"]
total=avbio.sum()
length=len(avbio)
a=total/length
print("Biology Average marks: ",a) #Average for all subjects

avchem=data[data["Exam name"]=="Chemistry"]
avchem=avchem["Marks"]
total=avchem.sum()
length=len(avchem)
b=total/length
print("Chemistry Average marks: ",b)


avphy=data[data["Exam name"]=="Physics"]
avphy=avphy["Marks"]
total=avphy.sum()
length=len(avphy)
c=total/length
print("Physics Average marks: ",c)


avsoc=data[data["Exam name"]=="Sociology"]
avsoc=avsoc["Marks"]
total=avsoc.sum()
length=len(avsoc)
d=total/length
print("Sociology Average marks: ",d)


avmath=data[data["Exam name"]=="Mathematics"]
avmath=avmath["Marks"]
total=avmath.sum()
length=len(avmath)
e=total/length
print("Math Average marks: ",e)


avphil=data[data["Exam name"]=="Philosophy"]
avphil=avphil["Marks"]
total=avphil.sum()
length=len(avphil)
f=total/length
print("Philosophy Average marks: ",f)
# Out:
# Biology Average marks:  47.89473684210526
#  Average marks:  48.7037037037037
# Chemistry Average marks:  51.76190476190476
# Sociology Average marks:  56.026315789473685
# Math Average marks:  47.648648648648646
# Philosophy Average marks:  46.026315789473685

# %% [markdown]
# **Part B** - Using the averages you just calculated, plot a Bar Graph showing the average marks of each subject

# %%
import matplotlib.pyplot as plt
subject=["Biology","Chemistry","Physics","Sociology","Maths","Philosophy"]
average=[a,b,c,d,e,f]
plt.bar(subject,average,fc="green") #Green bar graph
plt.show()

# %% [markdown]
# ---
# ## Question 4
# ---

# %% [markdown]
# **Part A** - Import the file "CatData.csv" and preprocess it to remove any null values

# %%
import pandas as pd
data1=pd.read_csv("CatData.csv")
print(data1.dropna()) #NULL values excluded
# Out:
#      Tail Length (cm)  Mass (kg)
# 0                18.1      3.750
# 1                18.6      3.800
# 2                19.5      3.250
# 3                19.3      3.450
# 4                19.0      3.650
# ..                ...        ...
# 337              20.7      4.000
# 338              20.2      3.400
# 339              19.3      3.775
# 340              21.0      4.100
# 341              19.8      3.775
#
# [342 rows x 2 columns]

# %% [markdown]
# **Part B** - Identify the independant and dependant variables (comment answer below)

# %%
# dependant variable(Y): Mass (kg)
# independant variable(X): Tail Length (cm)

# %% [markdown]
# **Part C** - Create a linear regression model using sklearn and fit it to the data you just imported

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
a= int(len (data1)*0.8)
train=data1[:a] #0 to range
test=data1[a:] #range till end

reg=linear_model.LinearRegression()
train1=np.array(train[["Tail Length (cm)"]]) #Independent Variable
train2=np.array(train[["Mass (kg)"]]) #Dependent Variable
reg.fit(train1,train2)
slope=reg.coef_
intercept=reg.intercept_

# %% [markdown]
# **Part D** - Print the values for slope and y-intercept

# %%
coef = reg.coef_
intr = reg.intercept_
print("Slope: ", coef)
print("Intercept: ",intr)
# Out:
# Slope:  [[0.48913766]]
# Intercept:  [-5.57328662]

# %% [markdown]
# **Part E** - Plot a scatter graph of the original data and a regression line on the same figure (example with dummy data shown below)
#
# ![](https://drive.google.com/uc?export=view&id=1o_NAsNjfx7zAh9m-UjvWB3rta6uraKdY)

# %%
plt.xlabel("Tail Length (cm)")
plt.ylabel("Mass (kg)")
plt.title("Tail Length vs Mass")
plt.scatter(train["Tail Length (cm)"],train["Mass (kg)"]) #to show scatter values
plt.plot(train1,train1*coef[0]+intr, color = 'Red')
plt.show()
